# %%
# %load_ext autoreload
# %autoreload 2
import importlib

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc

from nlpaug.util import Action

# %%
text = 'Un rápido zorro marrón salta sobre el perro perezoso'
aug = naw.SynonymAug(aug_src='wordnet', lang='spa')
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-3-7d7685e80101> in <module>
#       1 text = 'Un rápido zorro marrón salta sobre el perro perezoso'
#       2 aug = naw.SynonymAug(aug_src='wordnet', lang='spa')
# ----> 3 augmented_text = aug.augment(text)
#       4 print("Original:")
#       5 print(text)
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/base_augmenter.py in augment(self, data, n, num_thread)
#     115                 # Single Thread
#     116                 if num_thread == 1:
# --> 117                     augmented_results = [action_fx(clean_data) for _ in range(n)]
#     118
#     119                 # Multi Thread
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/base_augmenter.py in <listcomp>(.0)
#     115                 # Single Thread
#     116                 if num_thread == 1:
# --> 117                     augmented_results = [action_fx(clean_data) for _ in range(n)]
#     118
#     119                 # Multi Thread
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/augmenter/word/synonym.py in substitute(self, data)
#     117         original_tokens = doc.get_original_tokens()
#     118
# --> 119         pos = self.model.pos_tag(original_tokens)
#     120
#     121         aug_idxes = self._get_aug_idxes(pos)
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/model/word_dict/wordnet.py in pos_tag(cls, tokens)
#      49     @classmethod
#      50     def pos_tag(cls, tokens):
# ---> 51         return nltk.pos_tag(tokens)
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     163     :rtype: list(tuple(str, str))
#     164     """
# --> 165     tagger = _get_tagger(lang)
#     166     return _pos_tag(tokens, tagset, tagger, lang)
#     167
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     105         tagger.load(ap_russian_model_loc)
#     106     else:
# --> 107         tagger = PerceptronTagger()
#     108     return tagger
#     109
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nltk/tag/perceptron.py in __init__(self, load)
#     165         if load:
#     166             AP_MODEL_LOC = "file:" + str(
# --> 167                 find("taggers/averaged_perceptron_tagger/" + PICKLE)
#     168             )
#     169             self.load(AP_MODEL_LOC)
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger/averaged_perceptron_tagger.pickle
#
#   Searched in:
#     - '/home/hana/nltk_data'
#     - '/home/hana/anaconda3/envs/nlp2/nltk_data'
#     - '/home/hana/anaconda3/envs/nlp2/share/nltk_data'
#     - '/home/hana/anaconda3/envs/nlp2/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
text = 'hi how are you'
context_aug = naw.ContextualWordEmbsAug(
    model_path='bert-base-uncased', action="substitute")
augmented_text = context_aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-2a5844614a24> in <module>
#       1 text = 'hi how are you'
#       2 context_aug = naw.ContextualWordEmbsAug(
# ----> 3     model_path='bert-base-uncased', action="substitute")
#       4 augmented_text = context_aug.augment(text)
#       5 print("Original:")
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/augmenter/word/context_word_embs.py in __init__(self, model_path, model_type, action, top_k, name, aug_min, aug_max, aug_p, stopwords, batch_size, device, force_reload, stopwords_regex, verbose, silence, use_custom_api)
#      98         self.model = self.get_model(
#      99             model_path=model_path, model_type=self.model_type, device=device, force_reload=force_reload,
# --> 100             batch_size=batch_size, top_k=top_k, silence=silence, use_custom_api=use_custom_api)
#     101         # Override stopwords
#     102         # if stopwords and self.model_type in ['xlnet', 'roberta']:
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/augmenter/word/context_word_embs.py in get_model(cls, model_path, model_type, device, force_reload, batch_size, top_k, silence, use_custom_api)
#     532         top_k=None, silence=True, use_custom_api=False):
#     533         return init_context_word_embs_model(model_path, model_type, device, force_reload, batch_size, top_k,
# --> 534             silence, use_custom_api)
#     535
#     536     def substitute_back_reserved_stopwords(self, doc, reserved_stopword_tokens, change_seq):
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/augmenter/word/context_word_embs.py in init_context_word_embs_model(model_path, model_type, device, force_reload, batch_size, top_k, silence, use_custom_api)
#      32             model = nml.Roberta(model_path, device=device, top_k=top_k, silence=silence, batch_size=batch_size)
#      33         elif model_type == 'bert':
# ---> 34             model = nml.Bert(model_path, device=device, top_k=top_k, silence=silence, batch_size=batch_size)
#      35         else:
#      36             raise ValueError('Model type value is unexpected. Only support bert and roberta models.')
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/nlpaug/model/lang_models/bert.py in __init__(self, model_path, temperature, top_k, top_p, batch_size, device, silence)
#      31         self.model_path = model_path
#      32
# ---> 33         self.tokenizer = AutoTokenizer.from_pretrained(model_path)
#      34         self.mask_id = self.token2id(self.MASK_TOKEN)
#      35         self.pad_id = self.token2id(self.PAD_TOKEN)
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     462
#     463         # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 464         tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     465         config_tokenizer_class = tokenizer_config.get("tokenizer_class")
#     466
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/transformers/models/auto/tokenization_auto.py in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, **kwargs)
#     335             resume_download=resume_download,
#     336             local_files_only=local_files_only,
# --> 337             use_auth_token=use_auth_token,
#     338         )
#     339
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1497             user_agent=user_agent,
#    1498             use_auth_token=use_auth_token,
# -> 1499             local_files_only=local_files_only,
#    1500         )
#    1501     elif os.path.exists(url_or_filename):
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1753             logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
#    1754
# -> 1755             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1756
#    1757         logger.info(f"storing {url} in cache at {cache_path}")
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1610         initial=resume_size,
#    1611         desc="Downloading",
# -> 1612         disable=bool(logging.get_verbosity() == logging.NOTSET),
#    1613     )
#    1614     for chunk in r.iter_content(chunk_size=1024):
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# ~/anaconda3/envs/nlp2/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     114         if IProgress is None:  # #187 #451 #558 #872
#     115             raise ImportError(
# --> 116                 "IProgress not found. Please update jupyter and ipywidgets."
#     117                 " See https://ipywidgets.readthedocs.io/en/stable"
#     118                 "/user_install.html")
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
